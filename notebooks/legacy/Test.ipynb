# %%
import polars as pl

# %%
spy_eod = pl.read_parquet('data/options/EOD/with_greeks/SPY_etf_greeks.parquet')

# %%
spy_eod
# Out:
# shape: (9_296_197, 33)
# ┌────────────┬────────┬───────┬────────────┬───┬──────────┬────────────┬─────────────┬─────────────┐
# │ expiration ┆ strike ┆ right ┆ ms_of_day2 ┆ … ┆ vega_bid ┆ rho_bid    ┆ probaOutOfM ┆ probaOutOfM │
# │ ---        ┆ ---    ┆ ---   ┆ ---        ┆   ┆ ---      ┆ ---        ┆ _ask        ┆ _bid        │
# │ date       ┆ f64    ┆ str   ┆ i64        ┆   ┆ f32      ┆ f32        ┆ ---         ┆ ---         │
# │            ┆        ┆       ┆            ┆   ┆          ┆            ┆ f32         ┆ f32         │
# ╞════════════╪════════╪═══════╪════════════╪═══╪══════════╪════════════╪═════════════╪═════════════╡
# │ 2020-01-03 ┆ 314.5  ┆ p     ┆ 55040467   ┆ … ┆ 0.003357 ┆ -2.7397e-7 ┆ 0.987317    ┆ 0.992669    │
# │ 2020-01-03 ┆ 315.0  ┆ p     ┆ 56762572   ┆ … ┆ 0.003479 ┆ -2.7397e-7 ┆ 0.986832    ┆ 0.99238     │
# │ 2020-01-03 ┆ 315.5  ┆ p     ┆ 58294943   ┆ … ┆ 0.003612 ┆ -2.7397e-7 ┆ 0.986304    ┆ 0.992065    │
# ...
